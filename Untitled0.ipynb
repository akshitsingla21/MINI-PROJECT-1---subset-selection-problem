# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitsingla21/mini-project-python-subset-selection/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #mini project subset selection program

# %%
import random as r
S= set([-12,-3,-6,7,2,-2,6,3,9,-7,-5,-8,1,11,-9,-4])
for i in range(0,4368):
 S1=r.sample(S,5)
 if sum(S1)==0:
  print(S1)
# Out:
# [6, -5, 2, 1, -4]
# [9, 2, -4, 1, -8]
# [-4, -2, 6, 3, -3]
# [-3, 9, -7, 7, -6]
# [3, -6, 1, 11, -9]
# [-4, -9, 11, 7, -5]
# [-2, 1, 2, -8, 7]
# [6, -8, -9, 2, 9]
# [-6, -2, -12, 11, 9]
# [6, -8, -3, -4, 9]
# [-9, 7, -7, 6, 3]
# [-8, 3, 2, -6, 9]
# [-9, 11, -6, -2, 6]
# [3, 2, -12, 1, 6]
# [-8, -6, 11, 6, -3]
# [7, -12, 9, -7, 3]
# [-5, -6, 6, -2, 7]
# [-3, 9, -9, -4, 7]
# [11, -7, -4, -3, 3]
# [-5, 11, -4, 7, -9]
# [1, 7, 2, -2, -8]
# [1, -2, 2, 11, -12]
# [1, 2, 6, -3, -6]
# [2, 7, -3, 6, -12]
# [7, -8, -4, 11, -6]
# [-9, -7, 9, 11, -4]
# [11, -4, 6, -5, -8]
# [-4, -9, -7, 11, 9]
# [1, 2, -9, -5, 11]
# [-2, 7, 11, -7, -9]
# [9, 7, -9, -2, -5]
# [6, -5, 9, -6, -4]
# [1, -8, 7, -3, 3]
# [6, -12, 1, 11, -6]
# [9, 1, -4, 6, -12]
# [1, 6, 7, -9, -5]
# [-3, 11, -6, -5, 3]
# [1, 11, -2, -6, -4]
# [-2, -8, 11, 2, -3]
# [11, -2, -3, -12, 6]
# [6, -4, 3, 1, -6]
# [-5, -9, 11, 2, 1]
# [6, 3, -9, 7, -7]
# [3, 6, 2, -8, -3]
# [-8, -6, 9, 2, 3]
# [7, -9, -5, -4, 11]
# [9, -8, -5, 1, 3]
# ...
